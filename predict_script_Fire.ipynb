# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.2/872.2 kB 14.3 MB/s eta 0:00:00
# ...

# %%
import torch
from ultralytics import YOLO

# Load the model
model = YOLO('/content/drive/MyDrive/detection_Feu_Correcte/best (5).pt')

# %%
results_image = model.predict('/content/drive/MyDrive/detection_Feu_Correcte/P7.png', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/detection_Feu_Correcte/P7.png: 64x64 (no detections), 171.7ms
# Speed: 12.1ms preprocess, 171.7ms inference, 15.2ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/detect/predict
